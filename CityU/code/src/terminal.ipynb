# %% [markdown]
# # 0.必备预处理命令

# %% [markdown]
# ## 0.1 挂载云盘
# 通常只用点一次就行

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 0.2 切换工作路径
# 这里以切换到Git仓库为例

# %%
import os
path = "/content/drive/MyDrive/GitCloud/InternNote/CityU/code/src"
os.chdir(path)
os.listdir(path)
# Out:
# ['SS-svm:resnet18-imagenet-caltech256.ipynb',
#  'Template:cnn-minst.py',
#  'PT:resnet18-cifar100.py',
#  'Ensemble-max:resnet18.py',
#  'Ensemble-mean:resnet18.py',
#  'FT-max:resnet18-caltech256-cifar10.py',
#  'FT-max:resnet18-imagenet-cifar10.py',
#  'FT-max:resnet18-cifar100-cifar10.py',
#  'SA-recurrent:resnet18.py',
#  'Attention-recurrent:resnet18.py',
#  'Attention-transformer:resnet18.py']

# %% [markdown]
# ## 0.3 查看GPU情况
# 使用命令行运行脚本时必须链接GPU

# %%
# !nvidia-smi
# Out:
# Sun Aug 15 06:59:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     8W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # 1.终端命令

# %% [markdown]
# ## 1.1 Fine-Tuning:max

# %%
# !python FT-max:resnet18-imagenet-cifar10.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 117MB/s]
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/5]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.444978	TrainAccuracy: 16.00%	ValidationAccuracy: 6.16%
# Epoch [1/5]	Batch [200/1000]	Sample [10000/50000]	Loss: 0.705669	TrainAccuracy: 55.33%	ValidationAccuracy: 75.50%
# ...

# %%
# !python FT-max:resnet18-caltech256-cifar10.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/5]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.674739	TrainAccuracy: 6.00%	ValidationAccuracy: 9.02%
# Epoch [1/5]	Batch [200/1000]	Sample [10000/50000]	Loss: 0.642149	TrainAccuracy: 60.06%	ValidationAccuracy: 77.64%
# Epoch [1/5]	Batch [300/1000]	Sample [15000/50000]	Loss: 0.214683	TrainAccuracy: 71.80%	ValidationAccuracy: 84.04%
# Epoch [1/5]	Batch [400/1000]	Sample [20000/50000]	Loss: 0.322113	TrainAccuracy: 76.70%	ValidationAccuracy: 87.16%
# ...

# %%
# !python FT-max:resnet18-cifar100-cifar10.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/5]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.602170	TrainAccuracy: 4.00%	ValidationAccuracy: 6.94%
# Epoch [1/5]	Batch [200/1000]	Sample [10000/50000]	Loss: 0.491697	TrainAccuracy: 69.43%	ValidationAccuracy: 87.04%
# Epoch [1/5]	Batch [300/1000]	Sample [15000/50000]	Loss: 0.334194	TrainAccuracy: 78.22%	ValidationAccuracy: 90.22%
# Epoch [1/5]	Batch [400/1000]	Sample [20000/50000]	Loss: 0.279652	TrainAccuracy: 82.17%	ValidationAccuracy: 90.78%
# ...

# %% [markdown]
# ## 1.2 Fine-Tuning:esemble

# %%
# !python Ensemble-max:resnet18.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/5]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.375806	TrainAccuracy: 4.00%	ValidationAccuracy: 7.84%
# Epoch [1/5]	Batch [200/1000]	Sample [10000/50000]	Loss: 1.845638	TrainAccuracy: 47.29%	ValidationAccuracy: 69.30%
# Epoch [1/5]	Batch [300/1000]	Sample [15000/50000]	Loss: 1.734857	TrainAccuracy: 60.42%	ValidationAccuracy: 79.02%
# Epoch [1/5]	Batch [400/1000]	Sample [20000/50000]	Loss: 1.685279	TrainAccuracy: 67.33%	ValidationAccuracy: 82.74%
# ...

# %%
# !python Ensemble-mean\:resnet18.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/3]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.307571	TrainAccuracy: 4.00%	ValidationAccuracy: 8.08%
# Epoch [1/3]	Batch [200/1000]	Sample [10000/50000]	Loss: 1.888001	TrainAccuracy: 49.25%	ValidationAccuracy: 69.62%
# Epoch [1/3]	Batch [300/1000]	Sample [15000/50000]	Loss: 1.770574	TrainAccuracy: 65.63%	ValidationAccuracy: 79.34%
# Epoch [1/3]	Batch [400/1000]	Sample [20000/50000]	Loss: 1.714212	TrainAccuracy: 72.60%	ValidationAccuracy: 82.18%
# ...

# %% [markdown]
# ## 1.3 Attention

# %%
# !python SA-recurrent:resnet18.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# shape of train set: 50000
# device : cuda
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/10]	Batch [100/1000]	Sample [5000/50000]	Loss: 2.328435	TrainAccuracy: 10.00%	ValidationAccuracy: 10.08%
# Epoch [1/10]	Batch [200/1000]	Sample [10000/50000]	Loss: 2.312076	TrainAccuracy: 9.72%	ValidationAccuracy: 10.08%
# Epoch [1/10]	Batch [300/1000]	Sample [15000/50000]	Loss: 2.305868	TrainAccuracy: 10.06%	ValidationAccuracy: 10.08%
# Epoch [1/10]	Batch [400/1000]	Sample [20000/50000]	Loss: 2.303115	TrainAccuracy: 10.10%	ValidationAccuracy: 10.08%
# ...
